# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array([0,6])
y = np.array([0,6])
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array([0,5])
y = np.array([0,5])
plt.plot(x, y, 'o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array([2, 4, 6, 8])
y = np.array([2, 4, 6, 8])
#z = np.array([2, 4, 6, 8])
plt.plot(x, y)
plt.show()
# Out:
# C:\Users\kaifi\AppData\Local\Temp\ipykernel_12764\2736495033.py:7: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   plt.show()
